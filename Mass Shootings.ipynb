# %% [markdown]
# http://shootingtracker.com/wiki/Mass_Shootings_in_2013
#
# Mass shootings by weekday
#
# http://blog.coderstats.net/github/2013/event-types/

# %%
from lxml import html
import pandas as pd
import matplotlib.pyplot as plt

weekdays_short = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# %%
url ='http://shootingtracker.com/wiki/Mass_Shootings_in_2013'
xpath = '//*[@class="sortable"]'
 
tree = html.parse(url)
table = tree.xpath(xpath)[0]
raw_html = html.tostring(table)
 
df = pd.read_html(raw_html, header=0, parse_dates=[1])[0]
#df.to_csv('web-index-2013-all-scores.csv')
df.head(6)
# Out:
#       Number       Date  Alleged Shooter  Killed  Wounded        Location  \
# 0          1 2013-01-01  Carlito Montoya       4        0  Sacramento, CA
# 1  [1][2][3]        NaT              NaN     NaN      NaN             NaN
# 2          2 2013-01-01          Unknown       1        3   Hawthorne, CA
# 3     [4][5]        NaT              NaN     NaN      NaN             NaN
# 4          3 2013-01-01      Julian Sims       0        4  McKeesport, PA
# 5     [6][7]        NaT              NaN     NaN      NaN             NaN
#
#   References  NaN      nan.1
# 0  [1][2][3]  NaN  [1][2][3]
# 1        NaN  NaN        NaN
# 2     [4][5]  NaN     [4][5]
# 3        NaN  NaN        NaN
# 4     [6][7]  NaN     [6][7]
# 5        NaN  NaN        NaN
#
# [6 rows x 9 columns]

# %%
# The reference section messes up the table, remove useless cols and rows
df_data = df[[1,2,3,4,5]].dropna(how='all')
df_data['Shootings'] = 1

# %%
gdate = df_data.groupby('Date').sum()

# %%
dates = pd.date_range('2013-01-01', '2013-12-31')
# Fill non existing dates with zeros
gdate = gdate.reindex(dates, fill_value=0)

# %%
gdate.plot(figsize=(32, 12), linewidth=1.5)

# %%
df_data['Week'] = df_data['Date'].apply(lambda x: x.week)
df_data['Weekday'] = df_data['Date'].apply(lambda x: x.weekday())
grouped = df_data.groupby('Weekday').sum()
grouped.sort(inplace=True, ascending=False)
grouped.index = [weekdays_short[i] for i in grouped.index]
grouped[['Killed', 'Wounded']].plot(kind='barh')

# %%
weeks = range(1, 53)
def fill(series):
    return [series.index[w] for w in weeks if w in series.index]
    

grouped = df_data.groupby(['Weekday', 'Week']).sum()
image = [fill(grouped['Killed'][i]) for i in range(7)]

k=grouped['Killed'][0]
k.index.append(range(1, 53))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-6652a04ed314> in <module>()
#       5
#       6 grouped = df_data.groupby(['Weekday', 'Week']).sum()
# ----> 7 image = [fill(grouped['Killed'][i]) for i in range(7)]
#       8
#       9 k=grouped['Killed'][0]
#
# <ipython-input-6-6652a04ed314> in <listcomp>(.0)
#       5
#       6 grouped = df_data.groupby(['Weekday', 'Week']).sum()
# ----> 7 image = [fill(grouped['Killed'][i]) for i in range(7)]
#       8
#       9 k=grouped['Killed'][0]
#
# <ipython-input-6-6652a04ed314> in fill(series)
#       1 weeks = range(1, 53)
#       2 def fill(series):
# ----> 3     return [series.index[w] for w in weeks if w in series.index]
#       4
#       5
#
# <ipython-input-6-6652a04ed314> in <listcomp>(.0)
#       1 weeks = range(1, 53)
#       2 def fill(series):
# ----> 3     return [series.index[w] for w in weeks if w in series.index]
#       4
#       5
#
# /home/ramiro/anaconda/envs/datamining/lib/python3.3/site-packages/pandas/core/index.py in __getitem__(self, key)
#     617         arr_idx = self.view(np.ndarray)
#     618         if np.isscalar(key):
# --> 619             return arr_idx[key]
#     620         else:
#     621             if com._is_bool_indexer(key):
#
# IndexError: index out of bounds

# %%
fig, ax = plt.subplots(figsize=(16, 9))
ax.imshow(image, cmap=plt.cm.Greens, interpolation='nearest')
ax.set_title('Commits by weekday and week')

for pos in ['top', 'right', 'bottom', 'left']:
    ax.spines[pos].set_visible(False)

plt.yticks(range(7), weekdays_short)
plt.xticks(range(52), range(1, 53))
plt.show()
