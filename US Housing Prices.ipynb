# %% [markdown]
# DataIsUgly contest entry, see http://www.reddit.com/r/dataisugly/comments/23zwij/part_ii_of_the_worstof_rdataisbeautiful_contest/
#
# Data source: https://docs.google.com/spreadsheets/d/1f3sqcfHFaQzDIzh5vP4t1kE-uKhW5O501rBhmDwIOp8/pubhtml

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from utils import graphs3

# %%
df = pd.read_csv('csv/us-housing-prices.csv', index_col='City')

# %%
graphs3.barh(df.index,
     df[df.columns[0]],
     'img/us-housing-prices.png',
     figsize=(10, 14),
     title='US Housing Prices: How many square feet do you get for $1,000,000',
     footer='Data source: Reddit - http://j.mp/dataisugly1 | Author: Ramiro Gómez - ramiro.org')
