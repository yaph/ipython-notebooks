# %%
# %load_ext signature
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

from mpl_toolkits.basemap import Basemap

df = pd.read_csv('csv/POIBerlin.csv', error_bad_lines=False) #, usecols=['name', 'amenity', 'Longitude', 'Latitude']
df.columns
# Out:
# The signature extension is already loaded. To reload it, use:
#   %reload_ext signature
# Index(['﻿"osmid"', 'name', 'amenity', 'emergency', 'geological', 'historic',
#        'leisure', 'man_made', 'office', 'shop', 'sport', 'tourism', 'craft',
#        'Longitude', 'Latitude'],
#       dtype='object')

# %%
surveillance = df[df.man_made.notnull() & df.man_made.str.contains('surveillance')]

# %%
surveillance
# Out:
#          ﻿"osmid"                name     amenity emergency  geological  \
# 0        16541597                Aral        fuel       NaN         NaN
# 69       30015304       Deutsche Bank        bank       NaN         NaN
# 182      69226035  Leipziger Apotheke    pharmacy       NaN         NaN
# 185      69226073                Sixt  car_rental       NaN         NaN
# 572     249075198                 NaN         NaN       NaN         NaN
# 573     249075212                 NaN         NaN       NaN         NaN
# 574     249075213                 NaN         NaN       NaN         NaN
# 575     249075226                 NaN         NaN       NaN         NaN
# 576     249075227                 NaN         NaN       NaN         NaN
# 716     256898645                 NaN         NaN       NaN         NaN
# 717     256898646                 NaN         NaN       NaN         NaN
# 805     260762771                 NaN         NaN       NaN         NaN
# ...
