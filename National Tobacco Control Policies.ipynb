# %%
df.head()
# Out:
#            GHO (CODE)                                   GHO (DISPLAY)  \
# 0  TOBACCO_0000000454      National agency for tobacco control exists
# 1  TOBACCO_0000000459                                     Budget year
# 2  TOBACCO_0000000453  Government objectives on tobacco control exist
# 3  TOBACCO_0000000454      National agency for tobacco control exists
# 4  TOBACCO_0000000457                               Reported currency
#
#                                            GHO (URL) PUBLISHSTATE (CODE)  \
# 0  http://apps.who.int/gho/indicatorregistry/App_...           PUBLISHED
# 1  http://apps.who.int/gho/indicatorregistry/App_...           PUBLISHED
# 2  http://apps.who.int/gho/indicatorregistry/App_...           PUBLISHED
# 3  http://apps.who.int/gho/indicatorregistry/App_...           PUBLISHED
# 4  http://apps.who.int/gho/indicatorregistry/App_...           PUBLISHED
#
#   PUBLISHSTATE (DISPLAY)  PUBLISHSTATE (URL)  YEAR (CODE)  YEAR (DISPLAY)  \
# ...

# %% [markdown]
# This looks a bit messy as it contains a lot of useless data, so let's remove all columns that only contain `NaN` values.

# %%
df = df.dropna(axis=1, how='all')
df.head()
# Out:
#            GHO (CODE)                                   GHO (DISPLAY)  \
# 0  TOBACCO_0000000454      National agency for tobacco control exists
# 1  TOBACCO_0000000459                                     Budget year
# 2  TOBACCO_0000000453  Government objectives on tobacco control exist
# 3  TOBACCO_0000000454      National agency for tobacco control exists
# 4  TOBACCO_0000000457                               Reported currency
#
#                                            GHO (URL) PUBLISHSTATE (CODE)  \
# 0  http://apps.who.int/gho/indicatorregistry/App_...           PUBLISHED
# 1  http://apps.who.int/gho/indicatorregistry/App_...           PUBLISHED
# 2  http://apps.who.int/gho/indicatorregistry/App_...           PUBLISHED
# 3  http://apps.who.int/gho/indicatorregistry/App_...           PUBLISHED
# 4  http://apps.who.int/gho/indicatorregistry/App_...           PUBLISHED
#
#   PUBLISHSTATE (DISPLAY)  YEAR (CODE)  YEAR (DISPLAY) REGION (CODE)  \
# ...

# %% [markdown]
# Looks better.

# %%
df['YEAR (DISPLAY)'].value_counts()
# Out:
# 2010    1351
# dtype: int64

# %%
df['Display Value'].value_counts()
# Out:
# . . .    380
# Yes      290
# No        82
# 2008      54
# -         39
# 2         25
# 2010      23
# 1         22
# 3         19
# USD       17
# 2007      12
# 5         11
# EUR       10
# 2006       9
# 4          7
# ...
# THB         1
# 29500000    1
# PKR         1
# 2878257     1
# CUP         1
# 134715      1
# MVR         1
# 650000      1
# 3588680     1
# 1092        1
# 90552       1
# 5400000     1
# 37000000    1
# 23437214    1
# DZD         1
# Length: 305, dtype: int64

# %%
df.replace(['. . .', '-'], nan, inplace=True)
df = df.dropna(axis=1, how='all')
df['Display Value'].value_counts()
# Out:
# Yes     290
# No       82
# 2008     54
# 2        25
# 2010     23
# 1        22
# 3        19
# USD      17
# 2007     12
# 5        11
# EUR      10
# 2006      9
# 4         7
# XOF       6
# 2004      6
# ...
# 240000000    1
# THB          1
# 29500000     1
# PKR          1
# 2878257      1
# CUP          1
# AUD          1
# 134715       1
# MVR          1
# 650000       1
# 3588680      1
# 90552        1
# 37000000     1
# 23437214     1
# DZD          1
# Length: 303, dtype: int64

# %%
df_agency = df[df['GHO (DISPLAY)'] == 'Annual budget for tobacco control in US$ at official exchange rate']
df_agency['Display Value'].value_counts().plot(kind='bar')

# %%
df.head(30)
# Out:
#             GHO (CODE)                                      GHO (DISPLAY)  \
# 0   TOBACCO_0000000454         National agency for tobacco control exists
# 1   TOBACCO_0000000459                                        Budget year
# 2   TOBACCO_0000000453     Government objectives on tobacco control exist
# 3   TOBACCO_0000000454         National agency for tobacco control exists
# 4   TOBACCO_0000000457                                  Reported currency
# 5   TOBACCO_0000000453     Government objectives on tobacco control exist
# 6   TOBACCO_0000000456  Annual budget for tobacco control in currency ...
# 7   TOBACCO_0000000457                                  Reported currency
# 8   TOBACCO_0000000453     Government objectives on tobacco control exist
# 9   TOBACCO_0000000454         National agency for tobacco control exists
# 10  TOBACCO_0000000453     Government objectives on tobacco control exist
# 11  TOBACCO_0000000456  Annual budget for tobacco control in currency ...
# ...
